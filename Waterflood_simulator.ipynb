# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonioAt/waterflood_simulator/blob/main/Waterflood_simulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AntonioAt/waterflood_simulator.git
# %cd waterflood_simulator
# !python main.py
# Out:
# Cloning into 'waterflood_simulator'...
# remote: Enumerating objects: 126, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 126 (delta 53), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (126/126), 67.15 KiB | 6.10 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
# /content/waterflood_simulator/waterflood_simulator/waterflood_simulator/waterflood_simulator/waterflood_simulator/waterflood_simulator/waterflood_simulator
# ...
#   EXPANDED 1-D WATERFLOOD RESERVOIR SIMULATOR
#   Modular Multi-Script Version
# ...
#
# ...
#   CASE 1: Base-Case Waterflood
# ...
#
#    Step       Time       dt   Oil Rate    WCut%       CumOil      RF%
# ------------------------------------------------------------------------
#      44       77.2   2.2434      434.8     0.00        33556    27.08
#      46       81.8   2.1512      434.8     0.00        35565    28.70
# ...

# %% [markdown]
# **Case-1**

# %%
from IPython.display import Image, display
display(Image('case1_main.png'))
display(Image('case1_diagnostics.png'))# Lakukan hal yang sama untuk file lainnya

# %% [markdown]
# **Case-2**

# %%
from IPython.display import Image, display
display(Image('case2_main.png'))
display(Image('case2_diagnostics.png'))

# %% [markdown]
# **Comparison**

# %%
from IPython.display import Image, display
display(Image('case3_comparison.png'))

# %% [markdown]
# **Sensitivity Analyst**

# %%
from IPython.display import Image, display
display(Image('case4_sensitivity.png'))
